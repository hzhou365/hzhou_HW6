# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [raw]
# import os
#
# path = "../Images"
#
# if not os.path.exists("../Images"):
#     os.makedirs(path)

# %% [markdown]
# ## Generate Cities List

# %%
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities 
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=b90c1c5ef1cb295a1e1ebef479e8c56c&units=metric&q=

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
new_cities=[]

# set up lists to hold reponse info
lat = []
temp_max_in_Celsius = []
humidity=[]
cloudiness=[]
wind_speed=[]

print("Beginning Data Retrieval")    
print("-----------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    
    try:
        lat.append(response['coord']['lat'])
        temp_max_in_Celsius.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        
        new_cities.append(city)
        
        print(f"Processing Record xx of Set xx | {city}")
        
    except KeyError:
        print("City not found. Skipping...")
        continue
    
#print(len(new_cities))
#print(len(lat))
#print(len(temp_max))
#print(len(humidity))
#print(len(cloudiness))
#print(len(wind_speed))

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")

temp_max_in_Fahreneit=[x*(9/5)+32 for x in temp_max_in_Celsius]

# create a data frame from cities, lat, and temp
weather_dict = {
    "city": new_cities,
    "lat": lat,
    "temp_max": temp_max_in_Fahreneit,
    'humidity': humidity,
    'cloudiness': cloudiness,
    'wind_speed': wind_speed
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record xx of Set xx | yarensk
# Processing Record xx of Set xx | hermanus
# Processing Record xx of Set xx | punta arenas
# Processing Record xx of Set xx | mehamn
# Processing Record xx of Set xx | albany
# Processing Record xx of Set xx | barrow
# Processing Record xx of Set xx | manono
# Processing Record xx of Set xx | cidreira
# Processing Record xx of Set xx | severo-kurilsk
# Processing Record xx of Set xx | rikitea
# Processing Record xx of Set xx | jining
# Processing Record xx of Set xx | ribeira grande
# Processing Record xx of Set xx | bethel
# Processing Record xx of Set xx | maragogi
# Processing Record xx of Set xx | bubaque
# Processing Record xx of Set xx | yellowknife
# Processing Record xx of Set xx | dalen
# Processing Record xx of Set xx | hithadhoo
# Processing Record xx of Set xx | bandarbeyla
# Processing Record xx of Set xx | pangai
# Processing Record xx of Set xx | santa cruz
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.title("City Latitude vs Max Temperature(xx/xx/xx)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
    
plt.scatter(weather_data['lat'], weather_data['temp_max'] , marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid()

### Save Figure
plt.savefig("../Images/xxx.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.title("City Latitude vs Humidity(xx/xx/xx)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.scatter(weather_data['lat'], weather_data['humidity'] , marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.title("City Latitude vs Cloudiness(xx/xx/xx)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.scatter(weather_data['lat'], weather_data['cloudiness'] , marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.title("City Latitude vs Wind Speed (xx/xx/xx)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.scatter(weather_data['lat'], weather_data['wind_speed'] , marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.grid()

# %%
Analysis 

Observed trend 1 
Observed trend 2 
Observed trend 3
